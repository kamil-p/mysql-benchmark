# %%
from random import randrange

# %%
select_by_employ_id = "SELECT * FROM employees e LEFT JOIN salaries s ON s.emp_no = e.emp_no LEFT JOIN titles t ON t.emp_no = e.emp_no LEFT JOIN dept_manager dm ON dm.emp_no = e.emp_no LEFT JOIN dept_emp de ON de.emp_no = e.emp_no LEFT JOIN departments d ON d.dept_no = de.dept_no LEFT JOIN departments d2 ON d2.dept_no = dm.dept_no WHERE e.emp_no = {};"
select_by_salary = "SELECT * FROM employees e LEFT JOIN salaries s ON s.emp_no = e.emp_no LEFT JOIN titles t ON t.emp_no = e.emp_no LEFT JOIN dept_manager dm ON dm.emp_no = e.emp_no LEFT JOIN dept_emp de ON de.emp_no = e.emp_no LEFT JOIN departments d ON d.dept_no = de.dept_no LEFT JOIN departments d2 ON d2.dept_no = dm.dept_no WHERE s.salary >= {};"
select_by_hire = "SELECT * FROM employees e LEFT JOIN salaries s ON s.emp_no = e.emp_no LEFT JOIN titles t ON t.emp_no = e.emp_no LEFT JOIN dept_manager dm ON dm.emp_no = e.emp_no LEFT JOIN dept_emp de ON de.emp_no = e.emp_no LEFT JOIN departments d ON d.dept_no = de.dept_no LEFT JOIN departments d2 ON d2.dept_no = dm.dept_no WHERE s.salary >= {} AND hire_date = '1985-01-01';"
insert_employee = "INSERT IGNORE INTO `employees`.`employees` (`emp_no`, `birth_date`, `first_name`, `last_name`, `gender`, `hire_date`) VALUES ('{}', '1958-05-01', 'Sachin', 'Tsukuda', 'M', '1997-11-30');"
insert_salarie = "INSERT IGNORE INTO `employees`.`salaries` (`emp_no`, `salary`, `from_date`, `to_date`) VALUES ({}, {}, '2019-11-11', '1997-06-23');"

select_by_employ_id_cache = select_by_employ_id.format(randrange(1000000))
select_by_salary_cache = select_by_salary.format(randrange(1000000))
select_by_hire_cache = select_by_hire.format(randrange(10000000))

for i in range(10):
    print (select_by_employ_id.format(randrange(1000000)))
    print (select_by_salary.format(randrange(1000000)))
    print (select_by_hire.format(randrange(10000000)))
    print (insert_employee.format(randrange(10000000)))
    print (insert_salarie.format(randrange(1000000), randrange(10000000)))
    print (select_by_employ_id_cache)
    print (select_by_salary_cache)
    print (select_by_hire_cache)
# Out:
# SELECT * FROM employees e LEFT JOIN salaries s ON s.emp_no = e.emp_no LEFT JOIN titles t ON t.emp_no = e.emp_no LEFT JOIN dept_manager dm ON dm.emp_no = e.emp_no LEFT JOIN dept_emp de ON de.emp_no = e.emp_no LEFT JOIN departments d ON d.dept_no = de.dept_no LEFT JOIN departments d2 ON d2.dept_no = dm.dept_no WHERE e.emp_no = 824536;
# SELECT * FROM employees e LEFT JOIN salaries s ON s.emp_no = e.emp_no LEFT JOIN titles t ON t.emp_no = e.emp_no LEFT JOIN dept_manager dm ON dm.emp_no = e.emp_no LEFT JOIN dept_emp de ON de.emp_no = e.emp_no LEFT JOIN departments d ON d.dept_no = de.dept_no LEFT JOIN departments d2 ON d2.dept_no = dm.dept_no WHERE s.salary >= 886609;
# ...
